# %% [markdown]
# # ZERO CROSSING RATE

# %% [markdown]
#
#     The zero crossing rate is the rate of sign-changes along a signal, i.e., the rate at which the signal changes from positive to negative or back.It usualy has a consideramle diffrence in values for music involving continuous striking of drums etc.. with hands or stick, for instance metal and rock genres

# %%
import librosa as lr
import librosa.display
import matplotlib.pyplot as plt
import matplotlib.style as ms
# %matplotlib inline
import numpy as np
import os

# %% [markdown]
# Let's analyze a classical audio's zero crossing rate first

# %%
classical_audio='/home/vivek/Genre_Detection/genres/classical/classical.00000.au'
y , sr =lr.load(classical_audio)

# %%
#the feature returns a numpy array of shape (1,t)
#where element z[0,i] represents the fraction of zero crossing in the i-th frame
zero_crossing_rate=lr.feature.zero_crossing_rate(y)
zero_crossing_rate.shape
# Out:
# (1, 1293)

# %% [markdown]
# Mean of the numpy array thus obtained is taken as a feature for our classification problem

# %%
np.mean(zero_crossing_rate)
# Out:
# 0.0982227015661253

# %% [markdown]
# #### Visualizing the zero crossing

# %%
plt.figure(figsize=(8, 2))
lr.display.waveplot(y, sr=sr)

# %%
# Zooming in
n0 = 1000
n1 = 1100
plt.figure(figsize=(12, 4))
plt.plot(y[n0:n1])
plt.grid()

# %% [markdown]
# The no of zero crossings is 7 (including the beginning point), checking with librosa

# %%
zero_crossings=lr.zero_crossings(y[n0:n1])
print(sum(zero_crossings))
# Out:
# 15

# %% [markdown]
# Now loading a rock audio

# %%
metal_audio='/home/vivek/Genre_Detection/genres/metal/metal.00001.au'
x , sr1 = lr.load(metal_audio)

# %%
metal_crossing_rate=lr.feature.zero_crossing_rate(x)
np.mean(zero_crossing_rate)
# Out:
# 0.0982227015661253

# %% [markdown]
# It is quite clear that the diffrence is considerable, thus it can be a important feature for classification

# %%
plt.figure(figsize=(12, 4))
plt.plot(x[n0:n1])
plt.grid()

# %%
zero_crossings=lr.zero_crossings(x[n0:n1])
print(sum(zero_crossings))
# Out:
# 26

# %% [markdown]
# Zero crossings are significantly larger in genres like metal and rock...(don't compare the beginning and ending of the two genres,the diffrence might not be quite clear)

# %% [markdown]
# Sources : __[Towards data science](https://towardsdatascience.com/music-genre-classification-with-python-c714d032f0d8)__
#           __[Librosa documentation](https://librosa.github.io/librosa/index.html)__
